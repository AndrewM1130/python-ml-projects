# %%
import numpy as np
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
master = pd.read_csv('data/classast - pha.csv')

# %% [markdown]
# There are six unique classes of stars;

# %%
master
# Out:
#         a (AU)         e    i (deg)     w (deg)  Node (deg)     M (deg)  \
# 0     1.078066  0.826854  22.825495   31.382966   88.010681  215.528772
# 1     1.245304  0.335342  13.337482  276.893024  337.207958  104.155606
# 2     1.470264  0.559922   6.352995  285.852564   35.736768  174.626213
# 3     1.776025  0.650141  39.832538  267.791993  356.903343  173.188556
# 4     1.874123  0.764602   1.326400   43.388048  349.694944  235.158622
# ...        ...       ...        ...         ...         ...         ...
# 1743  1.662826  0.382487   0.874625  304.980506  221.156655  312.111572
# 1744  2.706630  0.764459  11.433742  282.994922  267.501145  344.253089
# 1745  2.037870  0.667525   8.906649  279.721935   64.690270   19.063147
# 1746  2.095193  0.654662   4.014503  145.429653   25.164523  340.766105
# 1747  2.804294  0.667236   4.724883  234.125980  183.574675  349.530160
#
#       q (AU)  Q (AU)  P (yr)  H (mag)  MOID (AU) class
# ...

# %%
master['class'].unique()
# Out:
# array(['APO*', 'ATE*', 'AMO*', 'APO', 'IEO*', 'ATE'], dtype=object)
